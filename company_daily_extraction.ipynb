# %%
from selenium import webdriver
from selenium.webdriver.edge.service import Service as EdgeService
from webdriver_manager.microsoft import EdgeChromiumDriverManager
from selenium.webdriver.edge.options import Options as EdgeOptions
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from docx import Document

import datetime
import time
import pandas as pd
import requests

# %%
# 设置 EdgeOptions
options = EdgeOptions()
options.add_argument("--headless")  # 无头模式
# 初始化 WebDriver
driver = webdriver.Edge(service=EdgeService(EdgeChromiumDriverManager().install()), options=options)

today = datetime.datetime.now().strftime("%m-%d")
yesterday = (datetime.datetime.now() - datetime.timedelta(days=1)).strftime("%m-%d")
companies = pd.read_csv("data/sichuan_new.csv")

# %%
current_month_day = datetime.datetime.now().strftime("%m-%d")

# 创建一个 Word 文档
doc = Document()
doc.add_heading(f'四川上市公司资讯 - {current_month_day}', level=1)

for index, row in companies.iterrows():
    # 打开 dataweb 的网址
    print(f"Source: {row["website"]}")
    driver.get(row["website"])
    time.sleep(3)  # 等待页面加载

    # 使用 BeautifulSoup 解析页面内容
    soup = BeautifulSoup(driver.page_source, "html.parser")
    qnb_list = soup.find('div', class_="qnb_list")
    for li in qnb_list.find_all("li"):
        time_span = li.find('span', class_='time')
        if time_span:
            time_text = time_span.text.strip()
            month_day = datetime.datetime.strptime(time_text, '%m-%d').strftime('%m-%d')
        if month_day == current_month_day:
            a_tag = li.find('a')
            if a_tag:
                href = a_tag.get('href')
                content = a_tag.text.strip()
                print(f'Href: {href}, Content: {content}')

                try:
                    response = requests.get(href)
                    response.raise_for_status()  # 检查请求是否成功
                    href_soup = BeautifulSoup(response.text, 'html.parser')

                    # 提取 <title>
                    title = href_soup.find('title')
                    title_text = title.text.strip() if title else "No Title"
                    # print(f'Title: {title_text}')

                    # 提取 <meta name="keywords">
                    meta_keywords = href_soup.find('meta', attrs={'name': 'keywords'})
                    keywords_content = meta_keywords.get('content', '').strip() if meta_keywords else "No Keywords"
                    # print(f'Keywords: {keywords_content}')

                    # 提取 <meta name="description">
                    meta_description = href_soup.find('meta', attrs={'name': 'description'})
                    description_content = meta_description.get('content', '').strip() if meta_description else "No Description"
                    # print(f'Description: {description_content}')

                    # 将信息写入 Word 文档
                    doc.add_paragraph(f'链接: {href}')  # 链接
                    doc.add_paragraph(f'标题: {title_text}')  # 标题
                    doc.add_paragraph(f'关键词: {keywords_content}')  # 关键词
                    doc.add_paragraph(f'描述: {description_content}')  # 描述
                    doc.add_paragraph('————' * 8)  # 中文分隔线

                except requests.RequestException as e:
                    print(f'Failed to retrieve {href}: {e}')

# 保存 Word 文档
doc.save(f'daily/四川上市公司资讯_{current_month_day}.docx')
# Out:
# Source: https://quote.eastmoney.com/unify/r/0.002466
# Source: https://quote.eastmoney.com/unify/r/0.000598
# Source: https://quote.eastmoney.com/unify/r/1.601838
# Href: http://stock.eastmoney.com/a/202503063338220095.html, Content: 银行股早盘调整
# Href: http://stock.eastmoney.com/a/202503063338205018.html, Content: 银行股早盘调整，中信银行跌超2%
# Source: https://quote.eastmoney.com/unify/r/0.002312
# Source: https://quote.eastmoney.com/unify/r/0.300841
# Href: http://finance.eastmoney.com/a/202503063338204385.html, Content: 康华生物股东减持59万股 占总股本0.451%
# Source: https://quote.eastmoney.com/unify/r/1.600603
# Source: https://quote.eastmoney.com/unify/r/0.000876
# Href: http://finance.eastmoney.com/a/202503063337643141.html, Content: 全国政协委员、新希望集团董事长刘永好：科技创新扎根田间地头 农业新引擎破土拔节
# Source: https://quote.eastmoney.com/unify/r/1.601208
# Source: https://quote.eastmoney.com/unify/r/0.000568
# Href: http://finance.eastmoney.com/a/202503063337956849.html, Content: 富时A50指数将纳入寒武纪、中国联通、国泰君安 两家消费龙头被剔除
# Source: https://quote.eastmoney.com/unify/r/0.000155
# Source: https://quote.eastmoney.com/unify/r/1.600039
# Source: https://quote.eastmoney.com/unify/r/0.000858
# Href: http://finance.eastmoney.com/a/202503063337831574.html, Content: 盘前有料丨经济主题记者会今日举行；国内成品油价下调……重要消息还有这些
# Href: http://finance.eastmoney.com/a/202503063337831127.html, Content: 五粮液拟定今年投资计划，涉及资金约26亿元；红花郎开瓶扫码政策调整丨酒业早参
# Source: https://quote.eastmoney.com/unify/r/0.002697
# Source: https://quote.eastmoney.com/unify/r/1.688709
# Source: https://quote.eastmoney.com/unify/r/0.000688
# Source: https://quote.eastmoney.com/unify/r/0.002497
# Source: https://quote.eastmoney.com/unify/r/0.301050
# Source: https://quote.eastmoney.com/unify/r/1.600793
# Source: https://quote.eastmoney.com/unify/r/1.688302
# Source: https://quote.eastmoney.com/unify/r/1.688283
# Source: https://quote.eastmoney.com/unify/r/0.300425
# Source: https://quote.eastmoney.com/unify/r/1.603477
# Source: https://quote.eastmoney.com/unify/r/1.688222
# Href: http://finance.eastmoney.com/a/202503063337841584.html, Content: 【研报掘金】机构：看好AI制药行业长期的发展潜力及前景
# Source: https://quote.eastmoney.com/unify/r/1.600391
# Source: https://quote.eastmoney.com/unify/r/0.002539
# Source: https://quote.eastmoney.com/unify/r/0.002749
# Source: https://quote.eastmoney.com/unify/r/1.603053
# Source: https://quote.eastmoney.com/unify/r/0.000593
# Source: https://quote.eastmoney.com/unify/r/0.300937
# Source: https://quote.eastmoney.com/unify/r/0.301239
# Source: https://quote.eastmoney.com/unify/r/0.002190
# Source: https://quote.eastmoney.com/unify/r/0.300987
# Source: https://quote.eastmoney.com/unify/r/1.600331
# Source: https://quote.eastmoney.com/unify/r/0.300535
# Source: https://quote.eastmoney.com/unify/r/0.002951
# Source: https://quote.eastmoney.com/unify/r/0.300463
# Source: https://quote.eastmoney.com/unify/r/0.002798
# Source: https://quote.eastmoney.com/unify/r/0.002259
# Source: https://quote.eastmoney.com/unify/r/1.600779
# Source: https://quote.eastmoney.com/unify/r/0.000586
# Source: https://quote.eastmoney.com/unify/r/1.688528
# Source: https://quote.eastmoney.com/unify/r/1.688776
# Source: https://quote.eastmoney.com/unify/r/1.688070
# Source: https://quote.eastmoney.com/unify/r/0.002480
# Source: https://quote.eastmoney.com/unify/r/0.002978
# Source: https://quote.eastmoney.com/unify/r/1.603333
# Source: https://quote.eastmoney.com/unify/r/0.300504
# Source: https://quote.eastmoney.com/unify/r/1.688319
# Source: https://quote.eastmoney.com/unify/r/0.836675
# Source: https://quote.eastmoney.com/unify/r/0.836260
# Source: https://quote.eastmoney.com/unify/r/0.833943
# Source: https://quote.eastmoney.com/unify/r/0.832566
# Source: https://quote.eastmoney.com/unify/r/0.301336
# Source: https://quote.eastmoney.com/unify/r/1.603759
# Href: http://finance.eastmoney.com/a/202503063337922111.html, Content: 机构风向标 | 海天股份(603759)2024年四季度已披露持仓机构仅4家
# Href: http://finance.eastmoney.com/a/202503063337921391.html, Content: 海天股份(603759.SH)：2024年年报净利润为3.05亿元
# Href: http://finance.eastmoney.com/a/202503063337831574.html, Content: 盘前有料丨经济主题记者会今日举行；国内成品油价下调……重要消息还有这些
# Source: https://quote.eastmoney.com/unify/r/0.000935
# Source: https://quote.eastmoney.com/unify/r/0.301256
# Source: https://quote.eastmoney.com/unify/r/0.002630
# Source: https://quote.eastmoney.com/unify/r/1.688737
# Source: https://quote.eastmoney.com/unify/r/0.002651
# Source: https://quote.eastmoney.com/unify/r/0.430425
# Href: http://finance.eastmoney.com/a/202503063337834157.html, Content: 乐创技术：公司将发挥技术优势 推动智能眼镜生产工艺提升
# Href: http://finance.eastmoney.com/a/202503063337629583.html, Content: A股三大指数5日全线收红 机器人概念股维持强势
# Source: https://quote.eastmoney.com/unify/r/0.833781
# Source: https://quote.eastmoney.com/unify/r/0.300022
# Source: https://quote.eastmoney.com/unify/r/0.300470
# Source: https://quote.eastmoney.com/unify/r/0.300432
# Source: https://quote.eastmoney.com/unify/r/1.600137
# Source: https://quote.eastmoney.com/unify/r/0.870199
# Source: https://quote.eastmoney.com/unify/r/1.600558
# Source: https://quote.eastmoney.com/unify/r/0.000509
# Source: https://quote.eastmoney.com/unify/r/0.301286
# Source: https://quote.eastmoney.com/unify/r/0.300440
# Source: https://quote.eastmoney.com/unify/r/0.301515
# Source: https://quote.eastmoney.com/unify/r/0.300865
# Source: https://quote.eastmoney.com/unify/r/0.300733
# Source: https://quote.eastmoney.com/unify/r/0.300789
# Source: https://quote.eastmoney.com/unify/r/0.301213
# Source: https://quote.eastmoney.com/unify/r/0.000731
# Source: https://quote.eastmoney.com/unify/r/0.002386
# Source: https://quote.eastmoney.com/unify/r/0.002946
# Source: https://quote.eastmoney.com/unify/r/0.003023
# Source: https://quote.eastmoney.com/unify/r/0.300547
# Source: https://quote.eastmoney.com/unify/r/0.000803
# Source: https://quote.eastmoney.com/unify/r/0.000790
# Source: https://quote.eastmoney.com/unify/r/0.000510
# Source: https://quote.eastmoney.com/unify/r/0.300434
# Source: https://quote.eastmoney.com/unify/r/1.600880
# Source: https://quote.eastmoney.com/unify/r/0.300414
# Source: https://quote.eastmoney.com/unify/r/0.002258
# Source: https://quote.eastmoney.com/unify/r/0.301596
# Source: https://quote.eastmoney.com/unify/r/1.688553
# Source: https://quote.eastmoney.com/unify/r/0.836239
# Source: https://quote.eastmoney.com/unify/r/0.002628
# Source: https://quote.eastmoney.com/unify/r/0.000912
# Source: https://quote.eastmoney.com/unify/r/0.300471
# Source: https://quote.eastmoney.com/unify/r/0.833230
# Source: https://quote.eastmoney.com/unify/r/1.688513
# Source: https://quote.eastmoney.com/unify/r/1.688696
# Href: http://finance.eastmoney.com/a/202503063338237010.html, Content: 全国人大代表、极米科技董事长钟波：建议探索将智能投影仪纳入以旧换新的可行性
# Href: http://finance.eastmoney.com/a/202503063338230754.html, Content: 全国人大代表、极米科技董事长钟波：创新知识产权保护模式 适应技术迭代节奏
# Href: http://finance.eastmoney.com/a/202503063337625129.html, Content: 全国人大代表、极米科技董事长钟波：创新专利保护模式 加强防范知识产权侵权
# Source: https://quote.eastmoney.com/unify/r/1.603317
# Source: https://quote.eastmoney.com/unify/r/0.000558
# Source: https://quote.eastmoney.com/unify/r/0.000710
# Source: https://quote.eastmoney.com/unify/r/0.300540
# Source: https://quote.eastmoney.com/unify/r/0.002272
# Source: https://quote.eastmoney.com/unify/r/0.000810
# Source: https://quote.eastmoney.com/unify/r/0.002357
# Source: https://quote.eastmoney.com/unify/r/0.300101
# Source: https://quote.eastmoney.com/unify/r/0.300820
# Source: https://quote.eastmoney.com/unify/r/0.300249
# Source: https://quote.eastmoney.com/unify/r/1.688053
# Source: https://quote.eastmoney.com/unify/r/0.300559
# Source: https://quote.eastmoney.com/unify/r/0.300019
# Source: https://quote.eastmoney.com/unify/r/1.600378
# Href: http://finance.eastmoney.com/a/202503063337828345.html, Content: A股定增一览：3家公司披露定增进展
# Source: https://quote.eastmoney.com/unify/r/1.601811
# Source: https://quote.eastmoney.com/unify/r/1.688636
# Source: https://quote.eastmoney.com/unify/r/1.603027
# Source: https://quote.eastmoney.com/unify/r/0.301117
# Source: https://quote.eastmoney.com/unify/r/0.300366
# Source: https://quote.eastmoney.com/unify/r/0.300492
# Source: https://quote.eastmoney.com/unify/r/0.001337
# Source: https://quote.eastmoney.com/unify/r/0.002926
# Source: https://quote.eastmoney.com/unify/r/1.688297
# Source: https://quote.eastmoney.com/unify/r/0.000757
# Source: https://quote.eastmoney.com/unify/r/0.001288
# Source: https://quote.eastmoney.com/unify/r/0.002818
# Source: https://quote.eastmoney.com/unify/r/1.600828
# Source: https://quote.eastmoney.com/unify/r/0.300780
# Source: https://quote.eastmoney.com/unify/r/0.002240
# Source: https://quote.eastmoney.com/unify/r/1.601107
# Source: https://quote.eastmoney.com/unify/r/1.603077
# Source: https://quote.eastmoney.com/unify/r/0.300370
# Source: https://quote.eastmoney.com/unify/r/1.601399
# Source: https://quote.eastmoney.com/unify/r/1.603809
# Source: https://quote.eastmoney.com/unify/r/0.300467
# Source: https://quote.eastmoney.com/unify/r/0.301172
# Source: https://quote.eastmoney.com/unify/r/1.600109
# Source: https://quote.eastmoney.com/unify/r/1.603261
# Source: https://quote.eastmoney.com/unify/r/1.600678
# Source: https://quote.eastmoney.com/unify/r/0.300127
# Source: https://quote.eastmoney.com/unify/r/0.002777
# Source: https://quote.eastmoney.com/unify/r/0.002366
# Source: https://quote.eastmoney.com/unify/r/0.300092
# Source: https://quote.eastmoney.com/unify/r/0.002935
# Source: https://quote.eastmoney.com/unify/r/1.600131
# Source: https://quote.eastmoney.com/unify/r/1.600353
# Source: https://quote.eastmoney.com/unify/r/0.002253
# Source: https://quote.eastmoney.com/unify/r/0.000628
# Source: https://quote.eastmoney.com/unify/r/1.603679
# Source: https://quote.eastmoney.com/unify/r/0.002268
# Source: https://quote.eastmoney.com/unify/r/1.600644
# Source: https://quote.eastmoney.com/unify/r/1.603327
# Source: https://quote.eastmoney.com/unify/r/0.002246
# Source: https://quote.eastmoney.com/unify/r/1.688311
# Source: https://quote.eastmoney.com/unify/r/0.000629
# Source: https://quote.eastmoney.com/unify/r/0.002977
# Source: https://quote.eastmoney.com/unify/r/1.600839
# Href: http://finance.eastmoney.com/a/202503063338222294.html, Content: 全国人大代表、长虹控股集团董事长柳江：推动数据产业突破三大瓶颈
# Href: http://finance.eastmoney.com/a/202503063338223910.html, Content: 长虹控股集团董事长柳江：长虹积极推动“数据+AI”融合
# Href: http://finance.eastmoney.com/a/202503063338177482.html, Content: 全国人大代表、长虹控股集团董事长柳江：加快可信数据空间建设 促进数字经济发展
# Href: http://finance.eastmoney.com/a/202503063337825419.html, Content: 全国人大代表、长虹控股集团董事长柳江：坚持科技创新 加速AI技术应用
# Href: http://finance.eastmoney.com/a/202503063337629628.html, Content: “人工智能+”：硬核科技加速走进产业竞技场
# Source: https://quote.eastmoney.com/unify/r/0.301233
# Source: https://quote.eastmoney.com/unify/r/1.688629
# Href: http://finance.eastmoney.com/a/202503063337629628.html, Content: “人工智能+”：硬核科技加速走进产业竞技场
# Source: https://quote.eastmoney.com/unify/r/1.688117
# Source: https://quote.eastmoney.com/unify/r/0.002023
# Source: https://quote.eastmoney.com/unify/r/1.688511
# Source: https://quote.eastmoney.com/unify/r/1.600979
# Source: https://quote.eastmoney.com/unify/r/1.688506
# Source: https://quote.eastmoney.com/unify/r/0.000888
# Source: https://quote.eastmoney.com/unify/r/0.002773
# Source: https://quote.eastmoney.com/unify/r/1.600674
# Source: https://quote.eastmoney.com/unify/r/1.600392
# Source: https://quote.eastmoney.com/unify/r/0.000801
# Source: https://quote.eastmoney.com/unify/r/0.300696
# Source: https://quote.eastmoney.com/unify/r/1.600505
# Source: https://quote.eastmoney.com/unify/r/1.600702
# Source: https://quote.eastmoney.com/unify/r/1.600875
# Source: https://quote.eastmoney.com/unify/r/0.002422
# Source: https://quote.eastmoney.com/unify/r/0.300678
# Source: https://quote.eastmoney.com/unify/r/0.300502
# Source: https://quote.eastmoney.com/unify/r/1.600101
# Source: https://quote.eastmoney.com/unify/r/1.600438
# Href: http://finance.eastmoney.com/a/202503063337831574.html, Content: 盘前有料丨经济主题记者会今日举行；国内成品油价下调……重要消息还有这些
# Href: http://finance.eastmoney.com/a/202503063337823830.html, Content: 通威异质结组件功率再破世界纪录；永太科技与复旦大学展开技术合作丨新能源早参
# Href: http://finance.eastmoney.com/a/202503063337849288.html, Content: A股股票回购一览：13家公司披露回购进展
# Href: http://finance.eastmoney.com/a/202503053337566136.html, Content: 事关新能源 曾毓群、刘汉元、李良彬、钟宝申发声
